# %% [markdown]
# # 선형 회귀

# %% [markdown]
# - 다항 회귀

# %%
import pandas as pd

df = pd.read_csv('data/Fish.csv')

# %%
perch_df = df.loc[df['Species'] == 'Perch']

perch_length = perch_df[['Length2']]
perch_weight = perch_df[['Weight']]

# %%
from sklearn.model_selection import train_test_split

# %%
train_input, test_input, train_target, test_target =\
train_test_split(perch_length, perch_weight)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(train_input, train_target)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[-19.30295647,   0.97676515]])

# %%
import matplotlib.pyplot as plt

plt.scatter(train_input, train_target)
plt.plot(15, 50, [15 * 37 - 667, 50 * 37 - 667])

# %%
lr.score(train_input, train_target)
lr.score(test_input, test_target)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 lr.score(train_input, train_target)
#       2 lr.score(test_input, test_target)
#
# TypeError: RegressorMixin.score() missing 1 required positional argument: 'y'

# %% [markdown]
# # 다항회귀

# %% [markdown]
# - 독립변수의 차수 늘리기
# - n차 함수의 형태

# %%
train_input['Length2_poly'] = train_input['Length2'] ** 2
test_input['Length2_poly'] = test_input['Length2'] *print(lr.coef_, lr.)* 2

# %%
lr = LinearRegression()
lr.fit(train_input, train_target)
# Out:
# LinearRegression()

# %%
lr.score(test_input, test_target)
# Out:
# 0.986679962708122

# %%
lr.predict([[14, 14 * 14]])
# Out:
# C:\Users\1-20\Desktop\DAMF2\ml\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[6.88919356]])

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [[-19.30295647   0.97676515]] [85.68461521]

# %% [markdown]
# ax **2 + bx + c 형태의 2차 함수 그래프에서 순서대로
# a값, b값, c값
