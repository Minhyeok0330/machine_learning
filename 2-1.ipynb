# %%
import pandas as pd
df = pd.read_csv('data/Fish.csv')

# %%
cond = df['Species'].isin(['Bream', 'Smelt'])
lw_df = df.loc[cond, ['Length2', 'Weight']]
fish_data = lw_df.values.tolist()

# %%
fish_target = [1] * 35 + [0] * 14

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier()

# %%
train_input = fish_data[:35]
train_target = fish_target[:35]

test_input = fish_data[35:]
test_target = fish_target[35:]

# %%
kn.fit(train_input, train_target)
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target)
# Out:
# 0.0

# %%
import numpy as np

# %%
input_arr = np.array(fish_data)
target_arr = np.array(fish_target)

# %%
np.random.seed(42)
index = np.arange(49)
np.random.shuffle(index)
index
# Out:
# array([13, 45, 47, 44, 17, 27, 26, 25, 31, 19, 12,  4, 34,  8,  3,  6, 40,
#        41, 46, 15,  9, 16, 24, 33, 30,  0, 43, 32,  5, 29, 11, 36,  1, 21,
#         2, 37, 35, 23, 39, 10, 22, 18, 48, 20,  7, 42, 14, 28, 38])

# %%
train_input = input_arr[index[:35]]
train_target = target_arr[index[:35]]

# %%
test_input = input_arr[index[35:]]
test_target = target_arr[index[35:]]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(train_input[:, 0], train_input[:, 1])
plt.scatter(test_input[:, 0], test_input[:, 1])

# %%
kn.fit(train_input, train_target)
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target)
# Out:
# 1.0

# %%
kn.predict(test_input)
# Out:
# array([0, 0, 1, 0, 1, 1, 1, 0, 1, 1, 0, 1, 1, 0])

# %% [markdown]
# ## iris

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
#setosa, versicolor
#petal_length, petal_width

# %%
cond = iris['species'].isin(['setosa', 'virginica'])
petal_lw_iris = iris.loc[cond, ['petal_length', 'petal_width']]
iris_data = petal_lw_iris.values.tolist()

# %%
iris_target = [1] * len(iris_setosa['petal_length'].tolist()) + [0] * len(iris_virginica['petal_length'].tolist())

# %%
input_arr = np.array(iris_data)
target_arr = np.array(iris_target)

# %%
index = np.arange(100)
np.random.shuffle(index)
index
# Out:
# array([76, 18, 82, 81, 79, 31, 78, 64, 55, 85, 45, 12, 36,  9, 19, 57, 20,
#        71, 56, 37, 29, 84, 26, 21, 41, 74,  2, 67, 98, 30, 22, 15, 58, 11,
#        48, 51, 66, 27, 38,  4, 32, 42, 88, 92, 16, 10, 50, 90, 75, 54, 65,
#        99,  6, 63,  0, 60, 69, 28, 40, 44, 68, 87, 93, 24, 25, 23, 97, 39,
#        72, 14, 47, 13, 61, 73, 33, 94, 17, 62, 86, 95, 53,  5, 96,  3, 49,
#        35, 80, 77, 34, 46,  7, 43, 70, 59, 91, 83,  1, 52, 89,  8])

# %%
train_input = input_arr[index[:50]]
train_target = target_arr[index[:50]]

# %%
test_input = input_arr[index[50:]]
test_target = target_arr[index[50:]]

# %%
plt.scatter(train_input[:, 0], train_input[:, 1])
plt.scatter(test_input[:, 0], test_input[:, 1])

# %%
kn.fit(train_input, train_target)
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target)
# Out:
# 1.0

# %%
iris_copy=iris.copy()
cond_t = iris['species'].isin(['setosa', 'versicolor'])

# %%
iris_copy_df = iris_copy.loc[cond_t, ['petal_length', 'petal_width']]
iris_copy_data = iris_copy_df.values

# %%
setosa_count = iris_copy.loc[iris_copy['species'] == 'setosa'].shape[0]
versicolor_count = iris_copy.loc[iris_copy['species'] == 'versicolor'].shape[0]

# %%
iris_copy_target = np.array([1] * setosa_count + [0] * versicolor_count)

# %%
index = list(range(setosa_count + versicolor_count))

# %%
import random

random.shuffle(index)

# %%
train_copy_input = iris_copy_data[index[:70]]
train_copy_target = iris_copy_target[index[:70]]

# %%
test_copy_input = iris_copy_data[index[70:]]
test_copy_target = iris_copy_target[index[70:]]

# %%
plt.scatter(train_copy_input[:, 0], train_copy_input[:, 1])
plt.scatter(test_copy_input[:, 0], test_copy_input[:, 1])

# %%
kn.fit(train_copy_input, train_copy_target)
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_copy_input, test_copy_target)
# Out:
# 1.0
